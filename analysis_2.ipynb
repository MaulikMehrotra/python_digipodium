# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# load the dataset
# look at the data(head,tail,sample)
# -get the information about the datatype(dtype)
# -get the information about the columns(info)
# -chech how many rows are missing from each column(isnull,isna)
# - get statistical information about the dataset(describe{statistical analysis})
# -if required clean the dataset
# -removes the rows with missing columns
# -remove the columns with missing values or they are not required
# -if required transform the dataset
# -convert the categorical columns to numerical columns
# -conver the numerical columns to categorical columns
# -if required create new columns
# -if required rename the columns
# -if required remove the duplicates
# -if required remove the outliers
# -if required scale the dataset(standerdizarion or normalization)
# -sort the dataset
# -visualize the data
# univariate analysis
# -visualizins a single column
# -histogram
# -boxplot
# -line
# -bar
# -pie
# -area
#
# bivariate analysis
# -visualizing  two columns
#   -scatter(bubble)
#   -line
#   -bar
#   -pie
#   -area
# multivariate analysis
# -visualizing more than two columns
# -scatter(buble)
# -surface

# %%
df=pd.read_json('flipkart_fashion_products_dataset.json')

# %%
df.head()
# Out:
#                                     _id actual_price average_rating brand  \
# 0  fa8e22d6-c0b6-5229-bb9e-ad52eda39a0a        2,999            3.9  York
# 1  893e6980-f2a0-531f-b056-34dd63fe912c        1,499            3.9  York
# 2  eb4c8eab-8206-59d0-bcd1-a724d96bf74f        2,999            3.9  York
# 3  3f3f97bb-5faf-57df-a9ff-1af24e2b1045        2,999            3.9  York
# 4  750caa3d-6264-53ca-8ce1-94118a1d8951        2,999            3.9  York
#
#                    category          crawled_at  \
# 0  Clothing and Accessories 2021-02-10 20:11:51
# 1  Clothing and Accessories 2021-02-10 20:11:52
# 2  Clothing and Accessories 2021-02-10 20:11:52
# 3  Clothing and Accessories 2021-02-10 20:11:53
# 4  Clothing and Accessories 2021-02-10 20:11:53
#
#                                          description discount  \
# 0  Yorker trackpants made from 100% rich combed c...  69% off
# 1  Yorker trackpants made from 100% rich combed c...  66% off
# ...

# %%
df.tail()
# Out:
#                                         _id actual_price average_rating brand  \
# 29995  3705c6bd-6f23-529a-9b64-15b8fc568efa        2,299                  Oka
# 29996  f2a683e4-634d-5a11-8950-2d56b924576d          799            3.8   Oka
# 29997  1efa858c-1360-59a6-9624-bb04eddb492c        4,999                  Oka
# 29998  9fdfdd22-487b-599b-8be6-5dd00eb987c5        3,125            3.8   Oka
# 29999  a5396fab-753c-5cd7-bad9-050964f95a0f        3,125                  Oka
#
#                        category          crawled_at  \
# 29995  Clothing and Accessories 2021-02-11 01:31:54
# 29996  Clothing and Accessories 2021-02-11 01:31:54
# 29997  Clothing and Accessories 2021-02-11 01:31:54
# 29998  Clothing and Accessories 2021-02-11 01:31:55
# 29999  Clothing and Accessories 2021-02-11 01:31:55
#
#                                              description discount  \
# 29995                                                     40% off
# ...

# %%
df.sample()
# Out:
#                                         _id actual_price average_rating brand  \
# 27878  f94cbe0a-eb97-57f7-8659-77c00dbc40d2        4,999            4.1    Pu
#
#                        category          crawled_at  \
# 27878  Clothing and Accessories 2021-02-11 01:11:23
#
#                                              description discount  \
# 27878  PRODUCT STORY   Dress yourself from head to to...  35% off
#
#                                                   images  out_of_stock  \
# 27878  [https://rukminim1.flixcart.com/image/128/128/...         False
#
#                     pid                                    product_details  \
# 27878  TKSFUY98UAURGMQV  [{'Color': 'Black'}, {'Pattern': 'Solid'}, {'S...
#
#           seller selling_price sub_category                 title  \
# 27878  RetailNet         3,249   Tracksuits  Solid Men Track Suit
#
#                                                      url
# 27878  https://www.flipkart.com/puma-solid-men-track-...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              30000 non-null  object
#  1   actual_price     30000 non-null  object
#  2   average_rating   30000 non-null  object
#  3   brand            30000 non-null  object
#  4   category         30000 non-null  object
#  5   crawled_at       30000 non-null  datetime64[ns]
#  6   description      30000 non-null  object
#  7   discount         30000 non-null  object
#  8   images           30000 non-null  object
#  9   out_of_stock     30000 non-null  bool
#  10  pid              30000 non-null  object
#  11  product_details  30000 non-null  object
#  12  seller           30000 non-null  object
#  13  selling_price    30000 non-null  object
#  14  sub_category     30000 non-null  object
#  15  title            30000 non-null  object
# ...

# %%
#removing unwanted columns
cols_to_delete=['_id','pid','url','images']
df.drop(cols_to_delete,axis=1,inplace=True)
df.head()
# Out:
#   actual_price average_rating brand                  category  \
# 0        2,999            3.9  York  Clothing and Accessories
# 1        1,499            3.9  York  Clothing and Accessories
# 2        2,999            3.9  York  Clothing and Accessories
# 3        2,999            3.9  York  Clothing and Accessories
# 4        2,999            3.9  York  Clothing and Accessories
#
#            crawled_at                                        description  \
# 0 2021-02-10 20:11:51  Yorker trackpants made from 100% rich combed c...
# 1 2021-02-10 20:11:52  Yorker trackpants made from 100% rich combed c...
# 2 2021-02-10 20:11:52  Yorker trackpants made from 100% rich combed c...
# 3 2021-02-10 20:11:53  Yorker trackpants made from 100% rich combed c...
# 4 2021-02-10 20:11:53  Yorker trackpants made from 100% rich combed c...
#
#   discount  out_of_stock                                    product_details  \
# ...

# %%
df['actual_price']
# Out:
# 0        2,999
# 1        1,499
# 2        2,999
# 3        2,999
# 4        2,999
#          ...
# 29995    2,299
# 29996      799
# 29997    4,999
# 29998    3,125
# 29999    3,125
# Name: actual_price, Length: 30000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   actual_price     30000 non-null  object
#  1   average_rating   30000 non-null  object
#  2   brand            30000 non-null  object
#  3   category         30000 non-null  object
#  4   crawled_at       30000 non-null  datetime64[ns]
#  5   description      30000 non-null  object
#  6   discount         30000 non-null  object
#  7   out_of_stock     30000 non-null  bool
#  8   product_details  30000 non-null  object
#  9   seller           30000 non-null  object
#  10  selling_price    30000 non-null  object
#  11  sub_category     30000 non-null  object
#  12  title            30000 non-null  object
# dtypes: bool(1), datetime64[ns](1), object(11)
# memory usage: 2.8+ MB

# %%
df.describe()
# Out:
#                           crawled_at
# count                          30000
# mean   2021-02-10 22:55:06.673900032
# min              2021-02-10 20:11:51
# 25%              2021-02-10 21:31:38
# 50%              2021-02-10 23:01:10
# 75%              2021-02-11 00:16:29
# max              2021-02-11 01:31:55

# %%
df['actual_price'].str.replace(',','')
# Out:
# 0        2999
# 1        1499
# 2        2999
# 3        2999
# 4        2999
#          ...
# 29995    2299
# 29996     799
# 29997    4999
# 29998    3125
# 29999    3125
# Name: actual_price, Length: 30000, dtype: object

# %%
def clean_price(price):
    if price is None:
        return np.nan
    elif isinstance(price,str):
        price=price.replace(',','')
        if price: 
          price=float(price)
        else:
            price=np.nan
        return price
    else:
        return price
    
df['actual_price']=df['actual_price'].apply(clean_price)

# %%
df['actual_price']
# Out:
# 0        2999.0
# 1        1499.0
# 2        2999.0
# 3        2999.0
# 4        2999.0
#           ...
# 29995    2299.0
# 29996     799.0
# 29997    4999.0
# 29998    3125.0
# 29999    3125.0
# Name: actual_price, Length: 30000, dtype: float64

# %%
df['actual_price'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# discount
# sellingprice

# %%
def clean_price(price):
    if price is None:
        return np.nan
    elif isinstance(price,str):
        price=price.replace('%','')
        price=price.replace('off','')
        if price: 
          price=float(price)
        else:
            price=np.nan
        return price
    else:
        return price
    
df['discount']=df['discount'].apply(clean_price)

# %%
def clean_price(price):
    if price is None:
        return np.nan
    elif isinstance(price,str):
        price=price.replace(',','')
        if price: 
          price=float(price)
        else:
            price=np.nan
        return price
    else:
        return price
    
df['selling_price']=df['selling_price'].apply(clean_price)

# %%
def clean_rating(value):
    if value is None:
        return np.nan()
    elif isinstance(value,str):
        if value:
            value=float(value)
        else:
            value=np.nan
        return  value
    else:
     return value

df['average_rating']=df['average_rating'].apply(clean_rating)

# %%
df.drop_duplicates(subset='actual_price')
# Out:
#        actual_price  average_rating brand                  category  \
# 0            2999.0             3.9  York  Clothing and Accessories
# 1            1499.0             3.9  York  Clothing and Accessories
# 5            4499.0             3.8  York  Clothing and Accessories
# 11           1800.0             3.3  York  Clothing and Accessories
# 13           2700.0             3.3  York  Clothing and Accessories
# ...             ...             ...   ...                       ...
# 29891        3375.0             3.8   Oka  Clothing and Accessories
# 29897        2475.0             NaN   Oka  Clothing and Accessories
# 29898        3649.0             3.8   Oka  Clothing and Accessories
# 29948        2825.0             3.8   Oka  Clothing and Accessories
# 29998        3125.0             3.8   Oka  Clothing and Accessories
#
#                crawled_at                                        description  \
# ...

# %%
print(df.columns.tolist())
# Out:
# ['actual_price', 'average_rating', 'brand', 'category', 'crawled_at', 'description', 'discount', 'out_of_stock', 'product_details', 'seller', 'selling_price', 'sub_category', 'title']

# %%
#rename a column
df.rename(columns={'product_details':'details'},inplace=True)

# %%
df.head(2)
# Out:
#    actual_price  average_rating brand                  category  \
# 0        2999.0             3.9  York  Clothing and Accessories
# 1        1499.0             3.9  York  Clothing and Accessories
#
#            crawled_at                                        description  \
# 0 2021-02-10 20:11:51  Yorker trackpants made from 100% rich combed c...
# 1 2021-02-10 20:11:52  Yorker trackpants made from 100% rich combed c...
#
#    discount  out_of_stock                                            details  \
# 0      69.0         False  [{'Style Code': '1005COMBO2'}, {'Closure': 'El...
# 1      66.0         False  [{'Style Code': '1005BLUE'}, {'Closure': 'Draw...
#
#               seller  selling_price sub_category  \
# 0  Shyam Enterprises          921.0   Bottomwear
# 1  Shyam Enterprises          499.0   Bottomwear
#
#                               title
# 0  Solid Men Multicolor Track Pants
# 1        Solid Men Blue Track Pants

# %%
df.sort_values(by=['actual_price','average_rating'], ascending=False,inplace=True)

# %%
#styling dataframe
pricesdf=df[['title','actual_price','discount','average_rating','selling_price']]

# %%
pricesdf['discount'].plot.hist(bins=20,figsize=(10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
pricesdf.head(30).style.bar(subset=['actual_price','selling_price'],color='#330033')
# Out:
# <style type="text/css">
# #T_b9f93_row0_col1, #T_b9f93_row1_col1, #T_b9f93_row2_col1, #T_b9f93_row3_col1, #T_b9f93_row4_col1, #T_b9f93_row5_col1, #T_b9f93_row6_col1, #T_b9f93_row7_col1, #T_b9f93_row8_col1, #T_b9f93_row16_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #330033 100.0%, transparent 100.0%);
# }
# #T_b9f93_row0_col4, #T_b9f93_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #330033 97.5%, transparent 97.5%);
# }
# #T_b9f93_row1_col4, #T_b9f93_row2_col4, #T_b9f93_row3_col4, #T_b9f93_row5_col4, #T_b9f93_row17_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #330033 81.2%, transparent 81.2%);
# }
# #T_b9f93_row6_col4, #T_b9f93_row7_col4, #T_b9f93_row8_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #330033 65.0%, transparent 65.0%);
# }
# #T_b9f93_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #330033 99.9%, transparent 99.9%);
# }
# #T_b9f93_row9_col4 {
#   width: 10em;
# ...

# %%
pricesdf.head(30).style.background_gradient()
# Out:
# <style type="text/css">
# #T_83166_row0_col1, #T_83166_row0_col3, #T_83166_row1_col1, #T_83166_row2_col1, #T_83166_row3_col1, #T_83166_row4_col1, #T_83166_row5_col1, #T_83166_row6_col1, #T_83166_row6_col2, #T_83166_row7_col1, #T_83166_row7_col2, #T_83166_row8_col1, #T_83166_row8_col2, #T_83166_row9_col1, #T_83166_row11_col3, #T_83166_row12_col3, #T_83166_row14_col3, #T_83166_row15_col2, #T_83166_row16_col4, #T_83166_row19_col3, #T_83166_row20_col3, #T_83166_row21_col3, #T_83166_row22_col3, #T_83166_row23_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_83166_row0_col2, #T_83166_row4_col2, #T_83166_row9_col2, #T_83166_row14_col2, #T_83166_row24_col2, #T_83166_row25_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_83166_row0_col4, #T_83166_row4_col4, #T_83166_row9_col4 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_83166_row1_col2, #T_83166_row2_col2, #T_83166_row3_col2, #T_83166_row5_col2 {
#   background-color: #056faf;
# ...
