# %%
print("happy")
# Out:
# happy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_excel('Book1.xlsx',usecols=['LAST NAME','BASIC SALLARY'])
# Out:
#   LAST NAME  BASIC SALLARY
# 0    SHARMA          30000
# 1    PANDEY          25000
# 2       ALI          45000
# 3    PANDAY          25000
# 4    SHARMA          19500
# 5    KAPOOR          50000
# 6     SINGH          52000
# 7     SINGH          95000
# 8    KAPOOR          10000
# 9    PANDEY          30000

# %%
data=pd.read_excel('Book1.xlsx')
data.head() #first rows
# Out:
#    ID FIRST NAME LAST NAME  BASIC SALLARY  D.A.  H.R.A  T.A. DEPARTMENT  FINE
# 0   1        RAM    SHARMA          30000   0.5    0.8   0.1      SALES   600
# 1   2      VIJAY    PANDEY          25000   0.5    0.8   0.1   PURCHASE   299
# 2   3     IMRAN        ALI          45000   0.5    0.8   0.1        RND   588
# 3   4       AJAY    PANDAY          25000   0.5    0.8   0.1      SALES  1020
# 4   5      VIJAY    SHARMA          19500   0.3    0.6   0.1   PURCHASE   399

# %%
data
# Out:
#    ID  FIRST NAME LAST NAME  BASIC SALLARY  D.A.  H.R.A  T.A. DEPARTMENT  FINE
# 0   1         RAM    SHARMA          30000   0.5    0.8   0.1      SALES   600
# 1   2       VIJAY    PANDEY          25000   0.5    0.8   0.1   PURCHASE   299
# 2   3      IMRAN        ALI          45000   0.5    0.8   0.1        RND   588
# 3   4        AJAY    PANDAY          25000   0.5    0.8   0.1      SALES  1020
# 4   5       VIJAY    SHARMA          19500   0.3    0.6   0.1   PURCHASE   399
# 5   6      ROHAN     KAPOOR          50000   0.4    0.8   0.1        RND     0
# 6   7      VIDHYA     SINGH          52000   0.3    0.8   0.1      SALES     0
# 7   8      SURAJ      SINGH          95000   0.3    1.0   0.5  PURCHANSE   299
# 8   9       ARJUN    KAPOOR          10000   0.3    0.6   0.1        RND   299
# 9  10  ARUN KUMAR    PANDEY          30000   0.5    0.8   0.1   PURCHASE   299

# %%
data['FIRST NAME']#HOW TO SELECT A SINGLE COLUMN
# Out:
# 0           RAM
# 1         VIJAY
# 2        IMRAN
# 3          AJAY
# 4         VIJAY
# 5        ROHAN
# 6        VIDHYA
# 7        SURAJ
# 8         ARJUN
# 9    ARUN KUMAR
# Name: FIRST NAME, dtype: object

# %%
data['H.R.A']
# Out:
# 0    0.8
# 1    0.8
# 2    0.8
# 3    0.8
# 4    0.6
# 5    0.8
# 6    0.8
# 7    1.0
# 8    0.6
# 9    0.8
# Name: H.R.A, dtype: float64

# %%
data['BASIC SALLARY'].mean()
# Out:
# 38150.0

# %%
data[['FIRST NAME','BASIC SALLARY','FINE']]#LIST OF COLUMNS IN A SQUARE BRACKET
# Out:
#    FIRST NAME  BASIC SALLARY  FINE
# 0         RAM          30000   600
# 1       VIJAY          25000   299
# 2      IMRAN           45000   588
# 3        AJAY          25000  1020
# 4       VIJAY          19500   399
# 5      ROHAN           50000     0
# 6      VIDHYA          52000     0
# 7      SURAJ           95000   299
# 8       ARJUN          10000   299
# 9  ARUN KUMAR          30000   299

# %%
data.columns.tolist()#columns name in a list
# Out:
# ['ID',
#  'FIRST NAME',
#  'LAST NAME',
#  'BASIC SALLARY',
#  'D.A.',
#  'H.R.A',
#  'T.A.',
#  'DEPARTMENT',
#  'FINE']

# %%
data['BASIC SALLARY'].plot.bar()
# Out:
# <Axes: >

# %%
data.set_index('ID',inplace=True)
data
# Out:
#     FIRST NAME LAST NAME  BASIC SALLARY  D.A.  H.R.A  T.A. DEPARTMENT  FINE
# ID
# 1          RAM    SHARMA          30000   0.5    0.8   0.1      SALES   600
# 2        VIJAY    PANDEY          25000   0.5    0.8   0.1   PURCHASE   299
# 3       IMRAN        ALI          45000   0.5    0.8   0.1        RND   588
# 4         AJAY    PANDAY          25000   0.5    0.8   0.1      SALES  1020
# 5        VIJAY    SHARMA          19500   0.3    0.6   0.1   PURCHASE   399
# 6       ROHAN     KAPOOR          50000   0.4    0.8   0.1        RND     0
# 7       VIDHYA     SINGH          52000   0.3    0.8   0.1      SALES     0
# 8       SURAJ      SINGH          95000   0.3    1.0   0.5  PURCHANSE   299
# 9        ARJUN    KAPOOR          10000   0.3    0.6   0.1        RND   299
# 10  ARUN KUMAR    PANDEY          30000   0.5    0.8   0.1   PURCHASE   299

# %%
data['BASIC SALLARY'].plot()
# Out:
# <Axes: xlabel='ID'>

# %%
data['BASIC SALLARY'].plot.area()
# Out:
# <Axes: xlabel='ID'>

# %%
data['BASIC SALLARY'].plot.bar()
# Out:
# <Axes: xlabel='ID'>

# %%
data['BASIC SALLARY'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['BASIC SALLARY'].plot.box()
# Out:
# <Axes: >

# %%
data['BASIC SALLARY'].plot.box(figsize=(4,3))
# Out:
# <Axes: >

# %%
data['BASIC SALLARY'].plot.pie()
# Out:
# <Axes: ylabel='BASIC SALLARY'>

# %%
data['BASIC SALLARY'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data['BASIC SALLARY'].plot.pie(figsize=(4,4), autopct='%.1f%%')
# Out:
# <Axes: ylabel='BASIC SALLARY'>

# %%
data[['BASIC SALLARY','FINE']].plot()
# Out:
# <Axes: xlabel='ID'>

# %%
data['TOTAL SALLARY']=data['BASIC SALLARY'] - data['FINE'] + \
      (data['H.R.A']* data['BASIC SALLARY'])+ \
        (data['D.A.']*data['BASIC SALLARY'])+ \
           (data['T.A.']*data['BASIC SALLARY'])

# %%
data
# Out:
#     FIRST NAME LAST NAME  BASIC SALLARY  D.A.  H.R.A  T.A. DEPARTMENT  FINE  \
# ID
# 1          RAM    SHARMA          30000   0.5    0.8   0.1      SALES   600
# 2        VIJAY    PANDEY          25000   0.5    0.8   0.1   PURCHASE   299
# 3       IMRAN        ALI          45000   0.5    0.8   0.1        RND   588
# 4         AJAY    PANDAY          25000   0.5    0.8   0.1      SALES  1020
# 5        VIJAY    SHARMA          19500   0.3    0.6   0.1   PURCHASE   399
# 6       ROHAN     KAPOOR          50000   0.4    0.8   0.1        RND     0
# 7       VIDHYA     SINGH          52000   0.3    0.8   0.1      SALES     0
# 8       SURAJ      SINGH          95000   0.3    1.0   0.5  PURCHANSE   299
# 9        ARJUN    KAPOOR          10000   0.3    0.6   0.1        RND   299
# 10  ARUN KUMAR    PANDEY          30000   0.5    0.8   0.1   PURCHASE   299
#
#     TOTAL SALLARY
# ID
# 1         71400.0
# 2         59701.0
# 3        107412.0
# 4         58980.0
# 5         38601.0
# ...

# %%
data[['TOTAL SALLARY','BASIC SALLARY']].plot.bar(color=['#ff5555','green'])
# Out:
# <Axes: xlabel='ID'>

# %%
data[['TOTAL SALLARY','BASIC SALLARY']].plot.bar(color=['blue','green'])
# Out:
# <Axes: xlabel='ID'>
